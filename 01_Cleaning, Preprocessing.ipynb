# %% [markdown]
# # Accelerating Cleantech Advancements through NLP-Powered Text Mining and Knowledge Extraction
# ### Notebook 1: Data Cleaning and Preprocessing
#
# Authors: Muhammed K. Ç., Karsanth P., Andrea V.

# %%
# Import libraries
import pandas as pd
import numpy as np
import string
import re
import nltk
import spacy
from pathlib import Path
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer

# %% [markdown]
# # String Operations

# %% [markdown]
# ### Getting Know Data

# %%
# Read the dataset

file_path = Path("/cleantech_media_dataset_v1_20231109.csv")
df_x = pd.read_csv(file_path)

# %%
df = df_x.copy()

# %%
# Display basic information about the dataset
df.head()
# Out:
#    Unnamed: 0                                              title        date  \
# 0        1280  Qatar to Slash Emissions as LNG Expansion Adva...  2021-01-13
# 1        1281               India Launches Its First 700 MW PHWR  2021-01-15
# 2        1283              New Chapter for US-China Energy Trade  2021-01-20
# 3        1284  Japan: Slow Restarts Cast Doubt on 2030 Energy...  2021-01-22
# 4        1285     NYC Pension Funds to Divest Fossil Fuel Shares  2021-01-25
#
#   author                                            content       domain  \
# 0    NaN  ["Qatar Petroleum ( QP) is targeting aggressiv...  energyintel
# 1    NaN  ["• Nuclear Power Corp. of India Ltd. ( NPCIL)...  energyintel
# 2    NaN  ["New US President Joe Biden took office this ...  energyintel
# 3    NaN  ["The slow pace of Japanese reactor restarts c...  energyintel
# 4    NaN  ["Two of New York City's largest pension funds...  energyintel
#
#                                                  url
# 0  https://www.energyintel.com/0000017b-a7dc-de4c...
# 1  https://www.energyintel.com/0000017b-a7dc-de4c...
# 2  https://www.energyintel.com/0000017b-a7dc-de4c...
# 3  https://www.energyintel.com/0000017b-a7dc-de4c...
# 4  https://www.energyintel.com/0000017b-a7dc-de4c...

# %%
# Display basic information about the dataset
df.shape
# Out:
# (9607, 7)

# %%
# Display basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9607 entries, 0 to 9606
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9607 non-null   int64
#  1   title       9607 non-null   object
#  2   date        9607 non-null   object
#  3   author      31 non-null     object
#  4   content     9607 non-null   object
#  5   domain      9607 non-null   object
#  6   url         9607 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 525.5+ KB

# %%
# Check for null values in each column
for i in df.columns:
    print(i, df[i].isnull().sum())
# Out:
# Unnamed: 0 0
# title 0
# date 0
# author 9576
# content 0
# domain 0
# url 0

# %%
# Drop unnecessary columns
df.drop( columns = ["author", "url", "Unnamed: 0", "date"], inplace = True)

# %%
# Display information about the dataset after dropping columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9607 entries, 0 to 9606
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    9607 non-null   object
#  1   content  9607 non-null   object
#  2   domain   9607 non-null   object
# dtypes: object(3)
# memory usage: 225.3+ KB

# %%
# Explore the length distribution of the 'content' and 'title' columns
df["content"].str.len().describe()
# Out:
# count     9607.000000
# mean      4905.994483
# std       2833.833565
# min       1188.000000
# 25%       2770.000000
# 50%       4228.000000
# 75%       6284.500000
# max      19836.000000
# Name: content, dtype: float64

# %% [markdown]
# Average 4905 chars long

# %%
df.title.str.len().describe()
# Out:
# count    9607.000000
# mean       67.081503
# std        20.741027
# min        18.000000
# 25%        53.000000
# 50%        65.000000
# 75%        80.000000
# max       200.000000
# Name: title, dtype: float64

# %%
# Identify and display titles and content with maximum and minimum lengths
df.title[np.argmax(df.title.str.len())]
df.title[np.argmax(df.title.str.len())]
# Out:
# 'ESB and Bord na Móna announce first solar farm to be developed as part of their Solar Co-Development Agreement – delivering up to 500MW of solar energy to the national grid – pv magazine International'

# %%
df.title[np.argmin(df.title.str.len())]
# Out:
# 'A Bad Year for Gas'

# %%
df.content[np.argmax(df.content.str.len())]
# Out:
# '["By clicking `` Allow All \'\' you agree to the storing of cookies on your device to enhance site navigation, analyse site usage and support us in providing free open access scientific content. More info.", \'The electric vehicle battery market is growing rapidly as the demand for electric vehicles increases. According to some estimates, the global market for electric vehicle batteries is expected to reach $ 225.55 billion by 2027. This growth is driven by several factors, including increasing concerns about climate change, the falling cost of electric vehicle batteries, and government incentives and subsidies for electric vehicles.\', \'Electric vehicle batteries are a critical component of electric vehicles made from lithium-ion or other high-capacity cells. They provide the energy needed to propel the vehicle and perform other functions, such as powering the lights, the radio, and the heating and cooling system.\', \'Many companies produce electric vehicle batteries, including Tesla, Panasonic, LG Chem, and BYD Auto. These companies are competing to develop new technologies and materials that could improve the performance and efficiency of electric vehicle batteries, and they are investing heavily in research and development in this area.\', \'Lead-acid batteries are the oldest rechargeable batteries and are still used in some electric vehicles today. Lead-acid batteries are inexpensive and have a relatively long lifespan, but they are also heavy and have low energy density.\', \'Lithium-ion batteries are the most commonly used batteries for electric vehicles. They have a high energy density, a long lifespan, and a relatively low environmental impact. They are also lightweight and compact, making them well-suited for electric vehicles.\', \'Other types of batteries are also being developed for electric vehicles, including solid-state and lithium-sulfur batteries. These batteries can potentially improve the performance and efficiency of EVs, but they are still in the early stages of development.\', \'Electric vehicle batteries are used in various electric vehicles, including passenger cars, buses, and trucks. They are becoming increasingly popular due to their ability to store energy efficiently and their potential to reduce greenhouse gas emissions. As a result, they are expected to play a key role in the transition to a low-carbon transportation sector.\', \'Image Credit: Roman Zaiets/Shutterstock.com\', \'Tesla Model S is a popular luxury electric sedan powered by a lithium-ion battery pack and has a range of up to 405 miles.\', \'Electric vehicle batteries can also be used for energy storage on the grid. They can store excess energy from renewable energy sources, such as wind turbines or solar panels, and release it when needed. This can help to stabilize the grid and improve the reliability of renewable energy sources.\', \'EV batteries are being used in a variety of industrial applications, such as forklifts, baggage carts, and electric boats.\', \'Li-ion batteries are used in various portable electronic devices, such as laptops, tablets, and cell phones. They are popular due to their high energy density and long lifespan.\', \'Electric vehicle ( EV) battery technology has significantly developed in recent years. Latest advancements in this area include improved energy density, increased lifespan, reduced cost, lighter weight, improved safety, and increased charging speed.\', \'Researchers have made a significant advancement in the design of electric vehicle batteries, allowing them to be charged in just 10 minutes. This record-breaking achievement allows for a shorter charging time and a longer travel range for electric vehicles.\', "`` The need for smaller, faster-charging batteries is greater than ever. There are simply not enough batteries and critical raw materials, especially those produced domestically, to meet anticipated demand, \'\' said Chao-Yang Wang, the study\'s lead author.", \'The researchers introduc ...

# %%
df.content[np.argmin(df.content.str.len())]
# Out:
# "['Italy’ s Falck Renewables will sell its founding family’ s 60% holding in the company to an investment vehicle run by JPMorgan Chase & Co, in a deal valuing the company at nearly $ 3 billion.', 'Shares in Falck Renewables rose as much as 15% in Milan after adding more than 3% on Tuesday, when Bloomberg reported the family was weighing options for its stake.', 'Falck Renewables will sell the holding to JPMorgan’ s Infrastructure Investments Fund, according to a statement.', 'The price of 8.81 euros ( $ 10.25) per share, a premium of 29.2% to the 3-month volume weighted average share price, values the full company at just below $ 3 billion.', 'The agreement will trigger a mandatory cash tender offer at closing.', 'IIF will partner with Falck Renewables “ to accelerate its growth plan and reinforce its leadership position in the renewable energy sector, ” the Italian company said in the statement.', 'The Falcks are among Italy’ s oldest industrial dynasties, with a history in the steel industry dating back to the early 1900s.', 'Their first plant, at Sesto San Giovanni near to Milan, was one of the country’ s most iconic industrial sites until its closure in the 1990s.']"

# %% [markdown]
# There are many irrelevant characters in content column

# %%
# Explore the presence of specific keywords related to crime in the 'content' column
df.content.str.contains("terror").sum()
# Out:
# 24

# %%
df.content.str.contains("love").sum()
# Out:
# 457

# %%
# Create a DataFrame to check for the presence of multiple crime-related keywords
crime_list = ["terror", "criminal", "police", "law", "drug", "bribery", "burglary", "homicide", "victim", "corruption"]

# %%
df_crime =  pd.DataFrame({crime : df.content.str.contains(crime, re.IGNORECASE) for crime in crime_list})

# %%
df_crime.head()
# Out:
#    terror  criminal  police    law   drug  bribery  burglary  homicide  \
# 0   False     False   False  False  False    False     False     False
# 1   False     False   False  False  False    False     False     False
# 2   False     False   False  False  False    False     False     False
# 3    True     False   False  False  False    False     False     False
# 4   False     False    True  False  False    False     False     False
#
#    victim  corruption
# 0   False       False
# 1   False       False
# 2   False       False
# 3   False       False
# 4   False       False

# %%
# Display content with both 'terror' and 'law' keywords
selection = df_crime.query("terror & law")
len(selection)
# Out:
# 10

# %%
selection.head()
# Out:
#       terror  criminal  police   law   drug  bribery  burglary  homicide  \
# 1511    True     False   False  True  False    False     False     False
# 1582    True     False   False  True  False    False     False     False
# 1710    True     False   False  True  False    False     False     False
# 2058    True     False   False  True  False    False     False     False
# 2594    True     False    True  True  False    False     False     False
#
#       victim  corruption
# 1511   False        True
# 1582   False       False
# 1710   False       False
# 2058   False       False
# 2594   False        True

# %%
df.loc[selection.index][["title", "domain"]]
# Out:
#                                                   title           domain
# 1511                      What Will Happen With Russia?    cleantechnica
# 1582  MidwayUSA's Record Solar Install Shows That Cl...    cleantechnica
# 1710  Unpacking The Iron Law of Projects: Black Swan...    cleantechnica
# 2058  European Countries Plan To Make The North Sea ...    cleantechnica
# 2594           The 10 best marathons in the Middle East     greenprophet
# 4782  Obscure Electric Truck Maker Named Mack Emerge...    cleantechnica
# 4851    Check Out This Ukraine Electric Vehicle Webinar    cleantechnica
# 4914  Corporate America Calls for Invoking 25th Amen...  naturalgasintel
# 5139  ConocoPhillips Evaluating ‘ Options’ After Wil...  naturalgasintel
# 5141  Federal Judge Voids OK for ConocoPhillips’ Wil...  naturalgasintel

# %% [markdown]
# # Preporecessing

# %% [markdown]
# ### Punctuation

# %%
# Remove punctuation from 'title', 'content', and 'domain' columns
for i in df[["title", "content", "domain"]]:
    df[i] = df[i].apply(lambda x : x.translate(str.maketrans('', '',string.punctuation)))

# %%
df.head()
# Out:
#                                                title  \
# 0  Qatar to Slash Emissions as LNG Expansion Adva...
# 1               India Launches Its First 700 MW PHWR
# 2               New Chapter for USChina Energy Trade
# 3  Japan Slow Restarts Cast Doubt on 2030 Energy ...
# 4     NYC Pension Funds to Divest Fossil Fuel Shares
#
#                                              content       domain
# 0  Qatar Petroleum  QP is targeting aggressive cu...  energyintel
# 1  • Nuclear Power Corp of India Ltd  NPCIL synch...  energyintel
# 2  New US President Joe Biden took office this we...  energyintel
# 3  The slow pace of Japanese reactor restarts con...  energyintel
# 4  Two of New York Citys largest pension funds sa...  energyintel

# %% [markdown]
# ### Numbers Removal

# %%
# Remove numbers from 'title', 'content', and 'domain' columns
for i in df[["title", "content", "domain"]]:
    df[i] = df[i].apply(lambda x :x.translate(str.maketrans('', '', string.digits)))

# %%
df.head()
# Out:
#                                                title  \
# 0  Qatar to Slash Emissions as LNG Expansion Adva...
# 1                  India Launches Its First  MW PHWR
# 2               New Chapter for USChina Energy Trade
# 3     Japan Slow Restarts Cast Doubt on  Energy Plan
# 4     NYC Pension Funds to Divest Fossil Fuel Shares
#
#                                              content       domain
# 0  Qatar Petroleum  QP is targeting aggressive cu...  energyintel
# 1  • Nuclear Power Corp of India Ltd  NPCIL synch...  energyintel
# 2  New US President Joe Biden took office this we...  energyintel
# 3  The slow pace of Japanese reactor restarts con...  energyintel
# 4  Two of New York Citys largest pension funds sa...  energyintel

# %% [markdown]
# ### Lowercasing

# %%
# Convert text to lowercase for 'title', 'content', and 'domain' columns
for i in df.columns:
    df[i] = df[i].apply(lambda x: x.lower())

# %%
df.head()
# Out:
#                                                title  \
# 0  qatar to slash emissions as lng expansion adva...
# 1                  india launches its first  mw phwr
# 2               new chapter for uschina energy trade
# 3     japan slow restarts cast doubt on  energy plan
# 4     nyc pension funds to divest fossil fuel shares
#
#                                              content       domain
# 0  qatar petroleum  qp is targeting aggressive cu...  energyintel
# 1  • nuclear power corp of india ltd  npcil synch...  energyintel
# 2  new us president joe biden took office this we...  energyintel
# 3  the slow pace of japanese reactor restarts con...  energyintel
# 4  two of new york citys largest pension funds sa...  energyintel

# %% [markdown]
# ### Removing weird chars and tabs

# %%
# Remove weird characters and leading/trailing whitespaces
for i in df.columns:
    df[i] = df[i].apply(lambda x: re.sub(re.compile('[^a-zA-Z0-9\s]'), '', x))

# %%
df.head()
# Out:
#                                                title  \
# 0  qatar to slash emissions as lng expansion adva...
# 1                  india launches its first  mw phwr
# 2               new chapter for uschina energy trade
# 3     japan slow restarts cast doubt on  energy plan
# 4     nyc pension funds to divest fossil fuel shares
#
#                                              content       domain
# 0  qatar petroleum  qp is targeting aggressive cu...  energyintel
# 1   nuclear power corp of india ltd  npcil synchr...  energyintel
# 2  new us president joe biden took office this we...  energyintel
# 3  the slow pace of japanese reactor restarts con...  energyintel
# 4  two of new york citys largest pension funds sa...  energyintel

# %%
for i in df.columns:
    df[i] = df[i].apply(lambda x: x.lstrip())

# %%
df.head()
# Out:
#                                                title  \
# 0  qatar to slash emissions as lng expansion adva...
# 1                  india launches its first  mw phwr
# 2               new chapter for uschina energy trade
# 3     japan slow restarts cast doubt on  energy plan
# 4     nyc pension funds to divest fossil fuel shares
#
#                                              content       domain
# 0  qatar petroleum  qp is targeting aggressive cu...  energyintel
# 1  nuclear power corp of india ltd  npcil synchro...  energyintel
# 2  new us president joe biden took office this we...  energyintel
# 3  the slow pace of japanese reactor restarts con...  energyintel
# 4  two of new york citys largest pension funds sa...  energyintel

# %% [markdown]
# ### Tokenize Words

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def tokenize_words(text):
    doc = nlp(text)
    return [token.text for token in doc]

# %%
# Tokenize words using spaCy
# %%time
df["token_title"] = df["title"].apply(lambda x: tokenize_words(x))
# Out:
# CPU times: user 43.3 s, sys: 119 ms, total: 43.5 s
# Wall time: 43.7 s

# %%
# %%time

df["token_words_content"] = df["content"].apply(lambda x: tokenize_words(x))
# Out:
# CPU times: user 12min 37s, sys: 24 s, total: 13min 1s
# Wall time: 13min 5s

# %%
df["token_words_content"][1]
# Out:
# ['nuclear',
#  'power',
#  'corp',
#  'of',
#  'india',
#  'ltd',
#  ' ',
#  'npcil',
#  'synchronized',
#  'kakrapar',
#  'in',
#  'the',
#  'western',
#  'state',
#  'of',
#  'gujarat',
#  'to',
#  'the',
#  'grid',
#  'on',
#  'jan',
#  ' ',
#  'making',
#  'it',
#  'the',
#  'first',
#  'of',
#  'indias',
#  ' ',
#  'megawatt',
#  'indigenously',
#  'developed',
#  'pressurized',
#  'heavy',
#  'water',
#  'reactors',
#  ' ',
#  'phwrs',
#  'to',
#  'reach',
#  'this',
#  'milestone',
#  ' ',
#  'niw',
#  'sep',
#  'the',
#  'news',
#  'was',
#  'tweeted',
#  'by',
#  'anil',
#  'kakodkar',
#  'former',
#  'chairman',
#  'of',
#  'the',
#  'department',
#  'of',
#  'atomic',
#  'energy',
#  'who',
#  'said',
#  'that',
#  ' ',
#  'more',
#  'units',
#  'of',
#  'the',
#  'same',
#  'design',
#  'will',
#  'follow',
#  'three',
#  'of',
#  'these',
#  'are',
#  'currently',
#  'under',
#  'construction',
#  ' ',
#  'another',
#  'at',
#  'kakrapar',
#  'and',
#  'two',
#  'at',
#  'npcils',
#  'rajasthan',
#  'plant',
#  'they',
#  'will',
#  'be',
#  'followed',
#  'by',
#  'two',
#  'at',
#  'the',
#  'greenfield',
#  'gorakhpur',
#  'site',
#  'in',
#  'haryana',
#  'and',
#  'then',
#  'a',
#  'planned',
#  'unit',
#  'fleet',
#  'at',
#  'gorakhpur',
#  'and',
#  'three',
#  'other',
#  'sites',
#  'kakrapar',
#  'was',
#  'five',
#  'years',
#  'past',
#  'its',
#  ' ',
#  'completion',
#  'date',
#  'achieving',
#  'criticality',
#  'in',
#  'july',
#  '  ',
#  'years',
#  'after',
#  'construction',
#  'began',
#  'commercial',
#  'operations',
#  'are',
#  'slated',
#  'to',
#  'begin',
#  'in',
#  'march',
#  'according',
#  'to',
#  'npcils',
#  'website',
#  'although',
#  'that',
#  'deadline',
#  'will',
#  'likely',
#  'not',
#  'be',
#  'met',
#  'indias',
#  'nuclear',
#  'suppliers',
#  'should',
#  'be',
#  'feeling',
#  'some',
#  'relief',
#  'over',
#  'kakrapars',
#  'startup',
#  'although',
#  'order',
#  'flows',
#  'will',
#  'depend',
#  'on',
#  'how',
#  'quickly',
#  'npcil',
#  'can',
#  'get',
#  'other',
#  'projects',
#  'moving',
#  'and',
#  'the',
#  'course',
#  'of',
#  'the',
#  'covid',
#  'pandemic',
#  ' ',
#  'niw',
#  'dec',
#  ' ',
#  'the',
#  'inaugural',
#  'us',
#  'small',
#  'modular',
#  'reactor',
#  ' ',
#  'smr',
#  'project',
#  'has',
#  'moved',
#  'into',
#  'its',
#  'second',
#  'phase',
#  'with',
#  'fluor',
#  'and',
#  'its',
#  'nuscale',
#  'subsidiary',
#  'announcing',
#  'jan',
#  ' ',
#  'that',
#  'per',
#  'agreements',
#  'with',
#  'the',
#  'utah',
#  'associated',
#  'municipal',
#  'power',
#  'systems',
#  ' ',
#  'uamps',
#  'they',
#  ' ',
#  'are',
#  'to',
#  'develop',
#  'higher',
#  'maturity',
#  'cost',
#  'estimates',
#  'and',
#  'initial',
#  'project',
#  'planning',
#  'work',
#  'for',
#  'the',
#  'licensing',
#  'manufacturing',
#  'and',
#  'construction',
#  'of',
#  'the',
#  'cfpp',
#  ' ',
#  'carbon',
#  'free',
#  'power',
#  'project',
#  '  ',
#  'however',
#  'uamps',
#  'confirmed',
#  'to',
#  'energy',
#  'intelligence',
#  'that',
#  'committed',
#  'offtake',
#  'now',
#  'stands',
#  'at',
#  'just',
#  ' ',
#  'mw',
#  'for',
#  'what',
#  'was',
#  'planned',
#  'as',
#  'a',
#  ' ',
#  'mw',
#  'module',
#  'smr',
#  'plant',
#  'with',
#  'nuscale',
#  'providing',
#  'additional',
#  'options',
#  'for',
#  ' ',
#  'plant',
#  'size',
#  'configuration',
#  'uamps',
#  'could',
#  'decide',
#  'to',
#  'build',
#  'a',
#  'plant',
#  'ranging',
#  'from',
#  ' ',
#  'modules',
#  '  ',
#  'megawatts',
#  'to',
#  ' ',
#  'modules',
#  '  ',
#  'megawatts',
#  ' ',
#  'a',
#  'uamps',
#  'spokesman',
#  'wrote',
#  'in',
#  'an',
#  'email',
#  'in',
#  'early',
#  ' ',
#  'uamps',
#  'boasted',
#  'offtake',
#  'commitments',
#  'of',
#  ' ',
#  'mw',
#  'but',
#  'that',
#  'included',
#  'us',
#  'department',
#  'of',
#  'energy',
#  ' ',
#  'doe',
#  'plans',
#  'to',
#  'take',
#  'output',
#  'from',
#  'up',
#  'to',
#  'two',
#  ' ',
#  'mw',
#  'modules',
#  'those',
#  'plans',
#  'ended',
#  'last',
#  'year',
#  'with',
#  'the',
#  'doe',
#  'instead',
#  'offering',
#  '  ',
#  'billion',
#  'in',
#  'multiyear',
#  'funding',
#  'for',
#  'the',
#  'project',
#  'eight',
#  'uamps',
#  'subscribers',
#  'dropped',
#  'out',
#  'of',
#  'the',
#  'project',
#  'and',
#  'another',
#  'two',
#  'offtakers',
#  'substantially',
#  'reduced',
#  'their',
#  'commitments',
#  ' ',
#  'across',
#  'the',
#  'ocean',
#  'nuscale',
#  'has',
#  'launched',
#  'a',
#  'play',
#  'for',
#  'the',
#  'uk',
#  'market',
#  'via',
#  'a',
#  'memorandum',
#  'of',
#  'understanding',
#  'with',
#  'startup',
#  'clean',
#  'energy',
#  'firm',
#  'shearwater',
#  'energy',
#  'to',
#  'explore',
#  'the',
#  'deployment',
#  'of',
#  'hybrid',
#  'smr',
#  'and',
#  'wind',
#  'energy',
#  'projects',
#  'across',
#  'the',
#  'country',
#  'the',
#  'companies',
#  'are',
#  'hoping',
#  'to',
#  'score',
#  'a',
#  'flagship',
#  'site',
#  'at',
#  'or',
#  'near',
#  'the',
#  'wylfa',
#  'plant',
#  'in',
#  'north',
#  'wales',
#  'where',
#  'last',
#  'year',
#  'hitachi',
#  'decided',
#  'to',
#  'wind',
#  'down',
#  'its',
#  'advanced',
#  'boiling',
#  'water',
#  'reactor',
#  ' ',
#  'abwr',
#  'project',
#  'development',
#  'company',
#  ' ',
#  'niw',
#  'sep',
#  'a',
#  'wylfa',
#  'smrwind',
#  'plant',
#  ' ',
#  'will',
#  'provide',
#  ' ',
#  'gw',
#  'of',
#  'reliable',
#  'zerocarbon',
#  'electricity',
#  'at',
#  'a',
#  'fraction',
#  'of',
#  'the',
#  'cost',
#  'of',
#  'a',
#  'conventional',
#  'nuclear',
#  'power',
#  'station',
#  'with',
#  'surplus',
#  'energy',
#  'generation',
#  'focused',
#  'on',
#  'the',
#  'production',
#  'of',
#  'hydrogen',
#  'to',
#  'support',
#  'the',
#  'transport',
#  'sector',
#  's',
#  'transition',
#  'to',
#  'lowcarbon',
#  'fuels',
#  ' ',
#  'shearwater',
#  'ceo',
#  'simon',
#  'forster',
#  'said',
#  'in',
#  'a',
#  'jan',
#  ' ',
#  'statement',
#  'but',
#  'shearwater',
#  'was',
#  'only',
#  'incorporated',
#  'in',
#  ' ',
#  'and',
#  'any',
#  'way',
#  'forward',
#  'for',
#  'the',
#  'project',
#  'is',
#  'likely',
#  'to',
#  'depend',
#  'on',
#  'suitably',
#  'attractive',
#  'economics',
#  'a',
#  'uk',
#  'government',
#  'nuclear',
#  'subsidy',
#  'regime',
#  'plus',
#  'locking',
#  'in',
#  'a',
#  'site',
#  'that',
#  'may',
#  'be',
#  'grabbed',
#  'by',
#  'another',
#  'interested',
#  'consortium',
#  'first',
#  ' ',
#  'related']

# %%
# %%time

df["token_domain"] = df["domain"].apply(lambda x: tokenize_words(x))
# Out:
# CPU times: user 47.6 s, sys: 127 ms, total: 47.7 s
# Wall time: 47.6 s

# %%
df.head()
# Out:
#                                                title  \
# 0  qatar to slash emissions as lng expansion adva...
# 1                  india launches its first  mw phwr
# 2               new chapter for uschina energy trade
# 3     japan slow restarts cast doubt on  energy plan
# 4     nyc pension funds to divest fossil fuel shares
#
#                                              content       domain  \
# 0  qatar petroleum  qp is targeting aggressive cu...  energyintel
# 1  nuclear power corp of india ltd  npcil synchro...  energyintel
# 2  new us president joe biden took office this we...  energyintel
# 3  the slow pace of japanese reactor restarts con...  energyintel
# 4  two of new york citys largest pension funds sa...  energyintel
#
#                                          token_title  \
# 0  [qatar, to, slash, emissions, as, lng, expansi...
# 1         [india, launches, its, first,  , mw, phwr]
# 2        [new, chapter, for, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt, on,  , en...
# 4  [nyc, pension, funds, to, divest, fossil, fuel...
#
#                                  token_words_content   token_domain
# 0  [qatar, petroleum,  , qp, is, targeting, aggre...  [energyintel]
# 1  [nuclear, power, corp, of, india, ltd,  , npci...  [energyintel]
# 2  [new, us, president, joe, biden, took, office,...  [energyintel]
# 3  [the, slow, pace, of, japanese, reactor, resta...  [energyintel]
# 4  [two, of, new, york, citys, largest, pension, ...  [energyintel]

# %% [markdown]
# ### Tokenize Sentences

# %%
# Tokenize sentences using spaCy
def tokenize_sents(text):
    doc = nlp(text)
    return [sent.text for sent in doc.sents]

df["token_sents_content"] = df["content"].apply(lambda x: tokenize_sents(x))

# %%
df.head()
# Out:
#                                                title  \
# 0  qatar to slash emissions as lng expansion adva...
# 1                  india launches its first  mw phwr
# 2               new chapter for uschina energy trade
# 3     japan slow restarts cast doubt on  energy plan
# 4     nyc pension funds to divest fossil fuel shares
#
#                                              content       domain  \
# 0  qatar petroleum  qp is targeting aggressive cu...  energyintel
# 1  nuclear power corp of india ltd  npcil synchro...  energyintel
# 2  new us president joe biden took office this we...  energyintel
# 3  the slow pace of japanese reactor restarts con...  energyintel
# 4  two of new york citys largest pension funds sa...  energyintel
#
#                                          token_title  \
# 0  [qatar, to, slash, emissions, as, lng, expansi...
# 1         [india, launches, its, first,  , mw, phwr]
# 2        [new, chapter, for, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt, on,  , en...
# 4  [nyc, pension, funds, to, divest, fossil, fuel...
#
#                                  token_words_content   token_domain  \
# 0  [qatar, petroleum,  , qp, is, targeting, aggre...  [energyintel]
# 1  [nuclear, power, corp, of, india, ltd,  , npci...  [energyintel]
# 2  [new, us, president, joe, biden, took, office,...  [energyintel]
# 3  [the, slow, pace, of, japanese, reactor, resta...  [energyintel]
# 4  [two, of, new, york, citys, largest, pension, ...  [energyintel]
#
#                                  token_sents_content
# 0  [qatar petroleum  qp is targeting aggressive c...
# 1  [nuclear power corp of india ltd  npcil synchr...
# 2  [new us president joe biden took office this w...
# 3  [the slow pace of japanese reactor restarts co...
# 4  [two of new york citys largest pension funds s...

# %%
df.columns
# Out:
# Index(['title', 'content', 'domain', 'token_title', 'token_words_content',
#        'token_domain', 'token_sents_content'],
#       dtype='object')

# %% [markdown]
# ### Stopwords

# %%
# Remove stopwords using spaCy
stop_words_spacy = nlp.Defaults.stop_words

# %%
def remove_stopwords(text):
    return [word for word in text if word not in stop_words_spacy]

# %%
# %%time

df["token_title"] = df["token_title"].apply(lambda x: remove_stopwords(x))
# Out:
# CPU times: user 21.5 ms, sys: 28 µs, total: 21.6 ms
# Wall time: 21.3 ms

# %%
# %%time

df["token_domain"] = df["token_domain"].apply(lambda x: remove_stopwords(x))
# Out:
# CPU times: user 500 ms, sys: 2.13 ms, total: 502 ms
# Wall time: 495 ms

# %%
# %%time

df["token_words_content"] = df["token_words_content"].apply(lambda x: remove_stopwords(x))
# Out:
# CPU times: user 846 ms, sys: 16.9 ms, total: 863 ms
# Wall time: 862 ms

# %%
# %%time

df["token_sents_content"] = df["token_sents_content"].apply(lambda x: remove_stopwords(x))
# Out:
# CPU times: user 137 ms, sys: 2.05 ms, total: 139 ms
# Wall time: 138 ms

# %% [markdown]
# ### Tokenize Sentences without processing

# %% [markdown]
# We might need to keep sentence meaning for the future analysis, so we are doing sentence tokenizing without any preprocessing

# %%
df_y = df_x.copy()

# %%
# Tokenize sentences without any processin
# %%time

df["token_sents_content_without_process"] = df_y["content"].apply(lambda x: tokenize_sents(x))
# Out:
# CPU times: user 19min 59s, sys: 9 s, total: 20min 8s
# Wall time: 20min 6s

# %% [markdown]
# #### Comparing without processing and with processing results for sentence tokenize

# %%
df["token_sents_content"][1]
# Out:
# ['nuclear power corp of india ltd  npcil synchronized kakrapar in the western state of gujarat to the grid on jan  making it the first of indias  megawatt indigenously developed pressurized heavy water reactors  phwrs to reach this milestone  niw',
#  'sep',
#  'the news was tweeted by anil kakodkar former chairman of the department of atomic energy who said that  more units of the same design will follow three of these are currently under construction  another at kakrapar and two at npcils rajasthan plant they will be followed by two at the greenfield gorakhpur site in haryana and then a planned unit fleet at gorakhpur and three other sites kakrapar was five years past its  completion date achieving criticality in july   years after construction began commercial operations are slated to begin in march according to npcils website although that deadline will likely not be met indias nuclear suppliers should be feeling some relief over kakrapars startup although order flows will depend on how quickly npcil can get other projects moving and the course of the covid pandemic  niw dec  the inaugural us small modular reactor  smr project has moved into its second phase with fluor and its nuscale subsidiary announcing jan  that per agreements with the utah associated municipal power systems  uamps they  are to develop higher maturity cost estimates and initial project planning work for the licensing manufacturing and construction of the cfpp  carbon free power project   however uamps confirmed to energy intelligence that committed offtake now stands at just  mw for what was planned as a  mw module smr plant with nuscale providing additional options for  plant size configuration uamps could decide to build a plant ranging from  modules   megawatts to  modules   megawatts  a uamps spokesman wrote in an email in early  uamps boasted offtake commitments of  mw but that included us department of energy  doe plans to take output from up to two  mw modules those plans ended last year with the doe instead offering   billion in multiyear funding for the project eight uamps subscribers dropped out of the project and another two offtakers substantially reduced their commitments  across the ocean nuscale has launched a play for the uk market via a memorandum of understanding with startup clean energy firm shearwater energy to explore the deployment of hybrid smr and wind energy projects across the country the companies are hoping to score a flagship site at or near the wylfa plant in north wales where last year hitachi decided to wind down its advanced boiling water reactor  abwr project development company  niw sep a wylfa smrwind plant  will provide  gw of reliable zerocarbon electricity at a fraction of the cost of a conventional nuclear power station with surplus energy generation focused on the production of hydrogen to support the transport sector s transition to lowcarbon fuels  shearwater ceo simon forster said in a jan  statement but shearwater was only incorporated in  and any way forward for the project is likely to depend on suitably attractive economics a uk government nuclear subsidy regime plus locking in a site that may be grabbed by another interested consortium first  related']

# %%
df["token_sents_content_without_process"][1]
# Out:
# ['["• Nuclear Power Corp. of India Ltd. ( NPCIL) synchronized Kakrapar-3 in the western state of Gujarat to the grid on Jan. 10, making it the first of India\'s 700 megawatt indigenously developed pressurized heavy water reactors ( PHWRs) to reach this milestone ( NIW Sep.18\'20).',
#  'The news was tweeted by Anil Kakodkar, former chairman of the Department of Atomic Energy, who said that 15 more units of the same design will follow.',
#  "Three of these are currently under construction -- another at Kakrapar, and two at NPCIL's Rajasthan plant.",
#  'They will be followed by two at the greenfield Gorakhpur site in Haryana, and then a planned 10-unit fleet at Gorakhpur and three other sites.',
#  'Kakrapar-3 was five years past its 2015 completion date, achieving criticality in July 2020, 10 years after construction began.',
#  "Commercial operations are slated to begin in March, according to NPCIL's website, although that deadline will likely not be met.",
#  "India's nuclear suppliers should be feeling some relief over Kakrapar-3's start-up, although order flows will depend on how quickly NPCIL can get other projects moving, and the course of the Covid-19 pandemic ( NIW Dec.11'20).",
#  '•',
#  "The inaugural US small modular reactor ( SMR) project has moved into its second phase with Fluor and its NuScale subsidiary announcing Jan. 11 that per agreements with the Utah Associated Municipal Power Systems ( Uamps) they `` are to develop higher maturity cost estimates and initial project planning work for the licensing, manufacturing and construction of the CFPP [ Carbon Free Power Project ]. ''",
#  'However, Uamps confirmed to Energy Intelligence that committed offtake now stands at just 100 MW for what was planned as a 750 MW, 12-module SMR plant.',
#  "With NuScale providing additional options for `` plant size configuration, Uamps could decide to build a plant ranging from 4 modules ( 308 megawatts) to 12 modules ( 924 megawatts), '' a Uamps spokesman wrote in an email.",
#  'In early 2019 Uamps boasted offtake commitments of 230 MW.',
#  'But that included US Department of Energy ( DOE) plans to take output from up to two 60 MW modules.',
#  'Those plans ended last year with the DOE instead offering $ 1.35 billion in multiyear funding for the project.',
#  'Eight Uamps subscribers dropped out of the project and another two offtakers substantially reduced their commitments.',
#  '•',
#  'Across the ocean NuScale has launched a play for the UK market via a memorandum of understanding with start-up clean energy firm Shearwater Energy to explore the deployment of hybrid SMR and wind energy projects across the country.',
#  "The companies are hoping to score a flagship site at or near the Wylfa plant in north Wales, where last year Hitachi decided to wind down its advanced boiling water reactor ( ABWR) project development company ( NIW Sep.18'20).",
#  "A Wylfa SMR-wind plant `` will provide 3 GW of reliable, zero-carbon electricity at a fraction of the cost of a conventional nuclear power station with surplus energy generation focused on the production of hydrogen to support the transport sector’ s transition to low-carbon fuels, '' Shearwater CEO Simon Forster said in a Jan. 12 statement.",
#  'But Shearwater was only incorporated in 2018, and any way forward for the project is likely to depend on suitably attractive economics, a UK government nuclear subsidy regime, plus locking in a site that may be grabbed by another interested consortium first ( related).',
#  '"]']

# %%
# Removing '•'

df["token_sents_content_without_process"] = df["token_sents_content_without_process"].apply(lambda x: [sentence.replace('•', '').strip() for sentence in x if sentence.replace('•', '').strip()])

# %%
df_t = df.copy()
df_z = df_t.copy()
df = df_z.copy()

# %%
df["token_sents_content_without_process"][1]
# Out:
# ['[" Nuclear Power Corp. of India Ltd. ( NPCIL) synchronized Kakrapar-3 in the western state of Gujarat to the grid on Jan. 10, making it the first of India\'s 700 megawatt indigenously developed pressurized heavy water reactors ( PHWRs) to reach this milestone ( NIW Sep.18\'20).',
#  'The news was tweeted by Anil Kakodkar, former chairman of the Department of Atomic Energy, who said that 15 more units of the same design will follow.',
#  "Three of these are currently under construction -- another at Kakrapar, and two at NPCIL's Rajasthan plant.",
#  'They will be followed by two at the greenfield Gorakhpur site in Haryana, and then a planned 10-unit fleet at Gorakhpur and three other sites.',
#  'Kakrapar-3 was five years past its 2015 completion date, achieving criticality in July 2020, 10 years after construction began.',
#  "Commercial operations are slated to begin in March, according to NPCIL's website, although that deadline will likely not be met.",
#  "India's nuclear suppliers should be feeling some relief over Kakrapar-3's start-up, although order flows will depend on how quickly NPCIL can get other projects moving, and the course of the Covid-19 pandemic ( NIW Dec.11'20).",
#  "The inaugural US small modular reactor ( SMR) project has moved into its second phase with Fluor and its NuScale subsidiary announcing Jan. 11 that per agreements with the Utah Associated Municipal Power Systems ( Uamps) they `` are to develop higher maturity cost estimates and initial project planning work for the licensing, manufacturing and construction of the CFPP [ Carbon Free Power Project ]. ''",
#  'However, Uamps confirmed to Energy Intelligence that committed offtake now stands at just 100 MW for what was planned as a 750 MW, 12-module SMR plant.',
#  "With NuScale providing additional options for `` plant size configuration, Uamps could decide to build a plant ranging from 4 modules ( 308 megawatts) to 12 modules ( 924 megawatts), '' a Uamps spokesman wrote in an email.",
#  'In early 2019 Uamps boasted offtake commitments of 230 MW.',
#  'But that included US Department of Energy ( DOE) plans to take output from up to two 60 MW modules.',
#  'Those plans ended last year with the DOE instead offering $ 1.35 billion in multiyear funding for the project.',
#  'Eight Uamps subscribers dropped out of the project and another two offtakers substantially reduced their commitments.',
#  'Across the ocean NuScale has launched a play for the UK market via a memorandum of understanding with start-up clean energy firm Shearwater Energy to explore the deployment of hybrid SMR and wind energy projects across the country.',
#  "The companies are hoping to score a flagship site at or near the Wylfa plant in north Wales, where last year Hitachi decided to wind down its advanced boiling water reactor ( ABWR) project development company ( NIW Sep.18'20).",
#  "A Wylfa SMR-wind plant `` will provide 3 GW of reliable, zero-carbon electricity at a fraction of the cost of a conventional nuclear power station with surplus energy generation focused on the production of hydrogen to support the transport sector’ s transition to low-carbon fuels, '' Shearwater CEO Simon Forster said in a Jan. 12 statement.",
#  'But Shearwater was only incorporated in 2018, and any way forward for the project is likely to depend on suitably attractive economics, a UK government nuclear subsidy regime, plus locking in a site that may be grabbed by another interested consortium first ( related).',
#  '"]']

# %% [markdown]
# ### Lemmatization

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
def nltk_lemma(text):
    nltk_lemmatizer = WordNetLemmatizer()
    nltk_lemmas = [nltk_lemmatizer.lemmatize(w) for w in text]
    return nltk_lemmas

# %%
df.columns
# Out:
# Index(['title', 'content', 'domain', 'token_title', 'token_words_content',
#        'token_domain', 'token_sents_content',
#        'token_sents_content_without_process'],
#       dtype='object')

# %%
# Lemmatization using NLTK
df["lemma_title"] = df["token_title"].apply(nltk_lemma)

# %%
df["lemma_content"] = df["token_words_content"].apply(nltk_lemma)

# %%
df.columns
# Out:
# Index(['title', 'content', 'domain', 'token_title', 'token_words_content',
#        'token_domain', 'token_sents_content',
#        'token_sents_content_without_process', 'lemma_title', 'lemma_content'],
#       dtype='object')

# %%
df["lemma_content"][1]
# Out:
# ['nuclear',
#  'power',
#  'corp',
#  'india',
#  'ltd',
#  ' ',
#  'npcil',
#  'synchronized',
#  'kakrapar',
#  'western',
#  'state',
#  'gujarat',
#  'grid',
#  'jan',
#  ' ',
#  'making',
#  'india',
#  ' ',
#  'megawatt',
#  'indigenously',
#  'developed',
#  'pressurized',
#  'heavy',
#  'water',
#  'reactor',
#  ' ',
#  'phwrs',
#  'reach',
#  'milestone',
#  ' ',
#  'niw',
#  'sep',
#  'news',
#  'tweeted',
#  'anil',
#  'kakodkar',
#  'chairman',
#  'department',
#  'atomic',
#  'energy',
#  'said',
#  ' ',
#  'unit',
#  'design',
#  'follow',
#  'currently',
#  'construction',
#  ' ',
#  'kakrapar',
#  'npcils',
#  'rajasthan',
#  'plant',
#  'followed',
#  'greenfield',
#  'gorakhpur',
#  'site',
#  'haryana',
#  'planned',
#  'unit',
#  'fleet',
#  'gorakhpur',
#  'site',
#  'kakrapar',
#  'year',
#  'past',
#  ' ',
#  'completion',
#  'date',
#  'achieving',
#  'criticality',
#  'july',
#  '  ',
#  'year',
#  'construction',
#  'began',
#  'commercial',
#  'operation',
#  'slated',
#  'begin',
#  'march',
#  'according',
#  'npcils',
#  'website',
#  'deadline',
#  'likely',
#  'met',
#  'india',
#  'nuclear',
#  'supplier',
#  'feeling',
#  'relief',
#  'kakrapars',
#  'startup',
#  'order',
#  'flow',
#  'depend',
#  'quickly',
#  'npcil',
#  'project',
#  'moving',
#  'course',
#  'covid',
#  'pandemic',
#  ' ',
#  'niw',
#  'dec',
#  ' ',
#  'inaugural',
#  'small',
#  'modular',
#  'reactor',
#  ' ',
#  'smr',
#  'project',
#  'moved',
#  'second',
#  'phase',
#  'fluor',
#  'nuscale',
#  'subsidiary',
#  'announcing',
#  'jan',
#  ' ',
#  'agreement',
#  'utah',
#  'associated',
#  'municipal',
#  'power',
#  'system',
#  ' ',
#  'uamps',
#  ' ',
#  'develop',
#  'higher',
#  'maturity',
#  'cost',
#  'estimate',
#  'initial',
#  'project',
#  'planning',
#  'work',
#  'licensing',
#  'manufacturing',
#  'construction',
#  'cfpp',
#  ' ',
#  'carbon',
#  'free',
#  'power',
#  'project',
#  '  ',
#  'uamps',
#  'confirmed',
#  'energy',
#  'intelligence',
#  'committed',
#  'offtake',
#  'stand',
#  ' ',
#  'mw',
#  'planned',
#  ' ',
#  'mw',
#  'module',
#  'smr',
#  'plant',
#  'nuscale',
#  'providing',
#  'additional',
#  'option',
#  ' ',
#  'plant',
#  'size',
#  'configuration',
#  'uamps',
#  'decide',
#  'build',
#  'plant',
#  'ranging',
#  ' ',
#  'module',
#  '  ',
#  'megawatt',
#  ' ',
#  'module',
#  '  ',
#  'megawatt',
#  ' ',
#  'uamps',
#  'spokesman',
#  'wrote',
#  'email',
#  'early',
#  ' ',
#  'uamps',
#  'boasted',
#  'offtake',
#  'commitment',
#  ' ',
#  'mw',
#  'included',
#  'department',
#  'energy',
#  ' ',
#  'doe',
#  'plan',
#  'output',
#  ' ',
#  'mw',
#  'module',
#  'plan',
#  'ended',
#  'year',
#  'doe',
#  'instead',
#  'offering',
#  '  ',
#  'billion',
#  'multiyear',
#  'funding',
#  'project',
#  'uamps',
#  'subscriber',
#  'dropped',
#  'project',
#  'offtakers',
#  'substantially',
#  'reduced',
#  'commitment',
#  ' ',
#  'ocean',
#  'nuscale',
#  'launched',
#  'play',
#  'uk',
#  'market',
#  'memorandum',
#  'understanding',
#  'startup',
#  'clean',
#  'energy',
#  'firm',
#  'shearwater',
#  'energy',
#  'explore',
#  'deployment',
#  'hybrid',
#  'smr',
#  'wind',
#  'energy',
#  'project',
#  'country',
#  'company',
#  'hoping',
#  'score',
#  'flagship',
#  'site',
#  'near',
#  'wylfa',
#  'plant',
#  'north',
#  'wale',
#  'year',
#  'hitachi',
#  'decided',
#  'wind',
#  'advanced',
#  'boiling',
#  'water',
#  'reactor',
#  ' ',
#  'abwr',
#  'project',
#  'development',
#  'company',
#  ' ',
#  'niw',
#  'sep',
#  'wylfa',
#  'smrwind',
#  'plant',
#  ' ',
#  'provide',
#  ' ',
#  'gw',
#  'reliable',
#  'zerocarbon',
#  'electricity',
#  'fraction',
#  'cost',
#  'conventional',
#  'nuclear',
#  'power',
#  'station',
#  'surplus',
#  'energy',
#  'generation',
#  'focused',
#  'production',
#  'hydrogen',
#  'support',
#  'transport',
#  'sector',
#  's',
#  'transition',
#  'lowcarbon',
#  'fuel',
#  ' ',
#  'shearwater',
#  'ceo',
#  'simon',
#  'forster',
#  'said',
#  'jan',
#  ' ',
#  'statement',
#  'shearwater',
#  'incorporated',
#  ' ',
#  'way',
#  'forward',
#  'project',
#  'likely',
#  'depend',
#  'suitably',
#  'attractive',
#  'economics',
#  'uk',
#  'government',
#  'nuclear',
#  'subsidy',
#  'regime',
#  'plus',
#  'locking',
#  'site',
#  'grabbed',
#  'interested',
#  'consortium',
#  ' ',
#  'related']

# %%
df.head()
# Out:
#                                                title  \
# 0  qatar to slash emissions as lng expansion adva...
# 1                  india launches its first  mw phwr
# 2               new chapter for uschina energy trade
# 3     japan slow restarts cast doubt on  energy plan
# 4     nyc pension funds to divest fossil fuel shares
#
#                                              content       domain  \
# 0  qatar petroleum  qp is targeting aggressive cu...  energyintel
# 1  nuclear power corp of india ltd  npcil synchro...  energyintel
# 2  new us president joe biden took office this we...  energyintel
# 3  the slow pace of japanese reactor restarts con...  energyintel
# 4  two of new york citys largest pension funds sa...  energyintel
#
#                                          token_title  \
# 0  [qatar, slash, emissions, lng, expansion, adva...
# 1                     [india, launches,  , mw, phwr]
# 2             [new, chapter, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt,  , energy...
# 4  [nyc, pension, funds, divest, fossil, fuel, sh...
#
#                                  token_words_content   token_domain  \
# 0  [qatar, petroleum,  , qp, targeting, aggressiv...  [energyintel]
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...  [energyintel]
# 2  [new, president, joe, biden, took, office, wee...  [energyintel]
# 3  [slow, pace, japanese, reactor, restarts, cont...  [energyintel]
# 4  [new, york, citys, largest, pension, funds, di...  [energyintel]
#
#                                  token_sents_content  \
# 0  [qatar petroleum  qp is targeting aggressive c...
# 1  [nuclear power corp of india ltd  npcil synchr...
# 2  [new us president joe biden took office this w...
# 3  [the slow pace of japanese reactor restarts co...
# 4  [two of new york citys largest pension funds s...
#
#                  token_sents_content_without_process  \
# 0  [["Qatar Petroleum ( QP) is targeting aggressi...
# 1  [[" Nuclear Power Corp. of India Ltd. ( NPCIL)...
# 2  [["New US President Joe Biden took office this...
# 3  [["The slow pace of Japanese reactor restarts ...
# 4  [["Two of New York City's largest pension fund...
#
#                                          lemma_title  \
# 0  [qatar, slash, emission, lng, expansion, advance]
# 1                       [india, launch,  , mw, phwr]
# 2             [new, chapter, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt,  , energy...
# 4  [nyc, pension, fund, divest, fossil, fuel, share]
#
#                                        lemma_content
# 0  [qatar, petroleum,  , qp, targeting, aggressiv...
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...
# 2  [new, president, joe, biden, took, office, wee...
# 3  [slow, pace, japanese, reactor, restarts, cont...
# 4  [new, york, city, largest, pension, fund, dive...

# %%
def spacy_lemma(text):
    text = " ".join([word for word in text])
    spacy_lemmas = [word.lemma_ for word in nlp(text)]
    return spacy_lemmas

# %%
# Lemmatization using spaCy
df["lemma_spacy_content"] = df["token_words_content"].apply(spacy_lemma)

# %%
df.head()
# Out:
#                                                title  \
# 0  qatar to slash emissions as lng expansion adva...
# 1                  india launches its first  mw phwr
# 2               new chapter for uschina energy trade
# 3     japan slow restarts cast doubt on  energy plan
# 4     nyc pension funds to divest fossil fuel shares
#
#                                              content       domain  \
# 0  qatar petroleum  qp is targeting aggressive cu...  energyintel
# 1  nuclear power corp of india ltd  npcil synchro...  energyintel
# 2  new us president joe biden took office this we...  energyintel
# 3  the slow pace of japanese reactor restarts con...  energyintel
# 4  two of new york citys largest pension funds sa...  energyintel
#
#                                          token_title  \
# 0  [qatar, slash, emissions, lng, expansion, adva...
# 1                     [india, launches,  , mw, phwr]
# 2             [new, chapter, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt,  , energy...
# 4  [nyc, pension, funds, divest, fossil, fuel, sh...
#
#                                  token_words_content   token_domain  \
# 0  [qatar, petroleum,  , qp, targeting, aggressiv...  [energyintel]
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...  [energyintel]
# 2  [new, president, joe, biden, took, office, wee...  [energyintel]
# 3  [slow, pace, japanese, reactor, restarts, cont...  [energyintel]
# 4  [new, york, citys, largest, pension, funds, di...  [energyintel]
#
#                                  token_sents_content  \
# 0  [qatar petroleum  qp is targeting aggressive c...
# 1  [nuclear power corp of india ltd  npcil synchr...
# 2  [new us president joe biden took office this w...
# 3  [the slow pace of japanese reactor restarts co...
# 4  [two of new york citys largest pension funds s...
#
#                  token_sents_content_without_process  \
# 0  [["Qatar Petroleum ( QP) is targeting aggressi...
# 1  [[" Nuclear Power Corp. of India Ltd. ( NPCIL)...
# 2  [["New US President Joe Biden took office this...
# 3  [["The slow pace of Japanese reactor restarts ...
# 4  [["Two of New York City's largest pension fund...
#
#                                          lemma_title  \
# 0  [qatar, slash, emission, lng, expansion, advance]
# 1                       [india, launch,  , mw, phwr]
# 2             [new, chapter, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt,  , energy...
# 4  [nyc, pension, fund, divest, fossil, fuel, share]
#
#                                        lemma_content  \
# 0  [qatar, petroleum,  , qp, targeting, aggressiv...
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...
# 2  [new, president, joe, biden, took, office, wee...
# 3  [slow, pace, japanese, reactor, restarts, cont...
# 4  [new, york, city, largest, pension, fund, dive...
#
#                                  lemma_spacy_content
# 0  [qatar, petroleum,   , qp, target, aggressive,...
# 1  [nuclear, power, corp, india, ltd,   , npcil, ...
# 2  [new, president, joe, biden, take, office, wee...
# 3  [slow, pace, japanese, reactor, restart, conti...
# 4  [new, york, city, large, pension, fund, divest...

# %%
df["lemma_spacy_content"][1]
# Out:
# ['nuclear',
#  'power',
#  'corp',
#  'india',
#  'ltd',
#  '  ',
#  'npcil',
#  'synchronize',
#  'kakrapar',
#  'western',
#  'state',
#  'gujarat',
#  'grid',
#  'jan',
#  '  ',
#  'make',
#  'indias',
#  '  ',
#  'megawatt',
#  'indigenously',
#  'develop',
#  'pressurize',
#  'heavy',
#  'water',
#  'reactor',
#  '  ',
#  'phwrs',
#  'reach',
#  'milestone',
#  '  ',
#  'niw',
#  'sep',
#  'news',
#  'tweet',
#  'anil',
#  'kakodkar',
#  'chairman',
#  'department',
#  'atomic',
#  'energy',
#  'say',
#  '  ',
#  'unit',
#  'design',
#  'follow',
#  'currently',
#  'construction',
#  '  ',
#  'kakrapar',
#  'npcil',
#  'rajasthan',
#  'plant',
#  'follow',
#  'greenfield',
#  'gorakhpur',
#  'site',
#  'haryana',
#  'plan',
#  'unit',
#  'fleet',
#  'gorakhpur',
#  'site',
#  'kakrapar',
#  'year',
#  'past',
#  '  ',
#  'completion',
#  'date',
#  'achieve',
#  'criticality',
#  'july',
#  '   ',
#  'year',
#  'construction',
#  'begin',
#  'commercial',
#  'operation',
#  'slate',
#  'begin',
#  'march',
#  'accord',
#  'npcil',
#  'website',
#  'deadline',
#  'likely',
#  'meet',
#  'indias',
#  'nuclear',
#  'supplier',
#  'feel',
#  'relief',
#  'kakrapar',
#  'startup',
#  'order',
#  'flow',
#  'depend',
#  'quickly',
#  'npcil',
#  'project',
#  'move',
#  'course',
#  'covid',
#  'pandemic',
#  '  ',
#  'niw',
#  'dec',
#  '  ',
#  'inaugural',
#  'small',
#  'modular',
#  'reactor',
#  '  ',
#  'smr',
#  'project',
#  'move',
#  'second',
#  'phase',
#  'fluor',
#  'nuscale',
#  'subsidiary',
#  'announce',
#  'jan',
#  '  ',
#  'agreement',
#  'utah',
#  'associate',
#  'municipal',
#  'power',
#  'system',
#  '  ',
#  'uamp',
#  '  ',
#  'develop',
#  'high',
#  'maturity',
#  'cost',
#  'estimate',
#  'initial',
#  'project',
#  'planning',
#  'work',
#  'licensing',
#  'manufacturing',
#  'construction',
#  'cfpp',
#  '  ',
#  'carbon',
#  'free',
#  'power',
#  'project',
#  '   ',
#  'uamp',
#  'confirm',
#  'energy',
#  'intelligence',
#  'commit',
#  'offtake',
#  'stand',
#  '  ',
#  'mw',
#  'plan',
#  '  ',
#  'mw',
#  'module',
#  'smr',
#  'plant',
#  'nuscale',
#  'provide',
#  'additional',
#  'option',
#  '  ',
#  'plant',
#  'size',
#  'configuration',
#  'uamp',
#  'decide',
#  'build',
#  'plant',
#  'range',
#  '  ',
#  'module',
#  '   ',
#  'megawatt',
#  '  ',
#  'module',
#  '   ',
#  'megawatt',
#  '  ',
#  'uamp',
#  'spokesman',
#  'write',
#  'email',
#  'early',
#  '  ',
#  'uamp',
#  'boast',
#  'offtake',
#  'commitment',
#  '  ',
#  'mw',
#  'include',
#  'department',
#  'energy',
#  '  ',
#  'doe',
#  'plan',
#  'output',
#  '  ',
#  'mw',
#  'module',
#  'plan',
#  'end',
#  'year',
#  'doe',
#  'instead',
#  'offer',
#  '   ',
#  'billion',
#  'multiyear',
#  'funding',
#  'project',
#  'uamp',
#  'subscriber',
#  'drop',
#  'project',
#  'offtaker',
#  'substantially',
#  'reduce',
#  'commitment',
#  '  ',
#  'ocean',
#  'nuscale',
#  'launch',
#  'play',
#  'uk',
#  'market',
#  'memorandum',
#  'understanding',
#  'startup',
#  'clean',
#  'energy',
#  'firm',
#  'shearwater',
#  'energy',
#  'explore',
#  'deployment',
#  'hybrid',
#  'smr',
#  'wind',
#  'energy',
#  'project',
#  'country',
#  'company',
#  'hope',
#  'score',
#  'flagship',
#  'site',
#  'near',
#  'wylfa',
#  'plant',
#  'north',
#  'wales',
#  'year',
#  'hitachi',
#  'decide',
#  'wind',
#  'advanced',
#  'boiling',
#  'water',
#  'reactor',
#  '  ',
#  'abwr',
#  'project',
#  'development',
#  'company',
#  '  ',
#  'niw',
#  'sep',
#  'wylfa',
#  'smrwind',
#  'plant',
#  '  ',
#  'provide',
#  '  ',
#  'gw',
#  'reliable',
#  'zerocarbon',
#  'electricity',
#  'fraction',
#  'cost',
#  'conventional',
#  'nuclear',
#  'power',
#  'station',
#  'surplus',
#  'energy',
#  'generation',
#  'focus',
#  'production',
#  'hydrogen',
#  'support',
#  'transport',
#  'sector',
#  's',
#  'transition',
#  'lowcarbon',
#  'fuel',
#  '  ',
#  'shearwater',
#  'ceo',
#  'simon',
#  'forster',
#  'say',
#  'jan',
#  '  ',
#  'statement',
#  'shearwater',
#  'incorporate',
#  '  ',
#  'way',
#  'forward',
#  'project',
#  'likely',
#  'depend',
#  'suitably',
#  'attractive',
#  'economic',
#  'uk',
#  'government',
#  'nuclear',
#  'subsidy',
#  'regime',
#  'plus',
#  'locking',
#  'site',
#  'grab',
#  'interested',
#  'consortium',
#  '  ',
#  'relate']

# %% [markdown]
# ### Stemming

# %%
sno = SnowballStemmer('english')

# %%
def stemmer(text):
    sno_stemms = [sno.stem(w) for w in text]
    return sno_stemms

# %%
# Stemming using NLTK
df["stemm_content"] = df["token_words_content"].apply(stemmer)

# %%
df.head()
# Out:
#                                                title  \
# 0  qatar to slash emissions as lng expansion adva...
# 1                  india launches its first  mw phwr
# 2               new chapter for uschina energy trade
# 3     japan slow restarts cast doubt on  energy plan
# 4     nyc pension funds to divest fossil fuel shares
#
#                                              content       domain  \
# 0  qatar petroleum  qp is targeting aggressive cu...  energyintel
# 1  nuclear power corp of india ltd  npcil synchro...  energyintel
# 2  new us president joe biden took office this we...  energyintel
# 3  the slow pace of japanese reactor restarts con...  energyintel
# 4  two of new york citys largest pension funds sa...  energyintel
#
#                                          token_title  \
# 0  [qatar, slash, emissions, lng, expansion, adva...
# 1                     [india, launches,  , mw, phwr]
# 2             [new, chapter, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt,  , energy...
# 4  [nyc, pension, funds, divest, fossil, fuel, sh...
#
#                                  token_words_content   token_domain  \
# 0  [qatar, petroleum,  , qp, targeting, aggressiv...  [energyintel]
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...  [energyintel]
# 2  [new, president, joe, biden, took, office, wee...  [energyintel]
# 3  [slow, pace, japanese, reactor, restarts, cont...  [energyintel]
# 4  [new, york, citys, largest, pension, funds, di...  [energyintel]
#
#                                  token_sents_content  \
# 0  [qatar petroleum  qp is targeting aggressive c...
# 1  [nuclear power corp of india ltd  npcil synchr...
# 2  [new us president joe biden took office this w...
# 3  [the slow pace of japanese reactor restarts co...
# 4  [two of new york citys largest pension funds s...
#
#                  token_sents_content_without_process  \
# 0  [["Qatar Petroleum ( QP) is targeting aggressi...
# 1  [[" Nuclear Power Corp. of India Ltd. ( NPCIL)...
# 2  [["New US President Joe Biden took office this...
# 3  [["The slow pace of Japanese reactor restarts ...
# 4  [["Two of New York City's largest pension fund...
#
#                                          lemma_title  \
# 0  [qatar, slash, emission, lng, expansion, advance]
# 1                       [india, launch,  , mw, phwr]
# 2             [new, chapter, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt,  , energy...
# 4  [nyc, pension, fund, divest, fossil, fuel, share]
#
#                                        lemma_content  \
# 0  [qatar, petroleum,  , qp, targeting, aggressiv...
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...
# 2  [new, president, joe, biden, took, office, wee...
# 3  [slow, pace, japanese, reactor, restarts, cont...
# 4  [new, york, city, largest, pension, fund, dive...
#
#                                  lemma_spacy_content  \
# 0  [qatar, petroleum,   , qp, target, aggressive,...
# 1  [nuclear, power, corp, india, ltd,   , npcil, ...
# 2  [new, president, joe, biden, take, office, wee...
# 3  [slow, pace, japanese, reactor, restart, conti...
# 4  [new, york, city, large, pension, fund, divest...
#
#                                        stemm_content
# 0  [qatar, petroleum,  , qp, target, aggress, cut...
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...
# 2  [new, presid, joe, biden, took, offic, week, u...
# 3  [slow, pace, japanes, reactor, restart, contin...
# 4  [new, york, citi, largest, pension, fund, dive...

# %%
df["stemm_content"][1]
# Out:
# ['nuclear',
#  'power',
#  'corp',
#  'india',
#  'ltd',
#  ' ',
#  'npcil',
#  'synchron',
#  'kakrapar',
#  'western',
#  'state',
#  'gujarat',
#  'grid',
#  'jan',
#  ' ',
#  'make',
#  'india',
#  ' ',
#  'megawatt',
#  'indigen',
#  'develop',
#  'pressur',
#  'heavi',
#  'water',
#  'reactor',
#  ' ',
#  'phwrs',
#  'reach',
#  'mileston',
#  ' ',
#  'niw',
#  'sep',
#  'news',
#  'tweet',
#  'anil',
#  'kakodkar',
#  'chairman',
#  'depart',
#  'atom',
#  'energi',
#  'said',
#  ' ',
#  'unit',
#  'design',
#  'follow',
#  'current',
#  'construct',
#  ' ',
#  'kakrapar',
#  'npcil',
#  'rajasthan',
#  'plant',
#  'follow',
#  'greenfield',
#  'gorakhpur',
#  'site',
#  'haryana',
#  'plan',
#  'unit',
#  'fleet',
#  'gorakhpur',
#  'site',
#  'kakrapar',
#  'year',
#  'past',
#  ' ',
#  'complet',
#  'date',
#  'achiev',
#  'critic',
#  'juli',
#  '  ',
#  'year',
#  'construct',
#  'began',
#  'commerci',
#  'oper',
#  'slate',
#  'begin',
#  'march',
#  'accord',
#  'npcil',
#  'websit',
#  'deadlin',
#  'like',
#  'met',
#  'india',
#  'nuclear',
#  'supplier',
#  'feel',
#  'relief',
#  'kakrapar',
#  'startup',
#  'order',
#  'flow',
#  'depend',
#  'quick',
#  'npcil',
#  'project',
#  'move',
#  'cours',
#  'covid',
#  'pandem',
#  ' ',
#  'niw',
#  'dec',
#  ' ',
#  'inaugur',
#  'small',
#  'modular',
#  'reactor',
#  ' ',
#  'smr',
#  'project',
#  'move',
#  'second',
#  'phase',
#  'fluor',
#  'nuscal',
#  'subsidiari',
#  'announc',
#  'jan',
#  ' ',
#  'agreement',
#  'utah',
#  'associ',
#  'municip',
#  'power',
#  'system',
#  ' ',
#  'uamp',
#  ' ',
#  'develop',
#  'higher',
#  'matur',
#  'cost',
#  'estim',
#  'initi',
#  'project',
#  'plan',
#  'work',
#  'licens',
#  'manufactur',
#  'construct',
#  'cfpp',
#  ' ',
#  'carbon',
#  'free',
#  'power',
#  'project',
#  '  ',
#  'uamp',
#  'confirm',
#  'energi',
#  'intellig',
#  'commit',
#  'offtak',
#  'stand',
#  ' ',
#  'mw',
#  'plan',
#  ' ',
#  'mw',
#  'modul',
#  'smr',
#  'plant',
#  'nuscal',
#  'provid',
#  'addit',
#  'option',
#  ' ',
#  'plant',
#  'size',
#  'configur',
#  'uamp',
#  'decid',
#  'build',
#  'plant',
#  'rang',
#  ' ',
#  'modul',
#  '  ',
#  'megawatt',
#  ' ',
#  'modul',
#  '  ',
#  'megawatt',
#  ' ',
#  'uamp',
#  'spokesman',
#  'wrote',
#  'email',
#  'earli',
#  ' ',
#  'uamp',
#  'boast',
#  'offtak',
#  'commit',
#  ' ',
#  'mw',
#  'includ',
#  'depart',
#  'energi',
#  ' ',
#  'doe',
#  'plan',
#  'output',
#  ' ',
#  'mw',
#  'modul',
#  'plan',
#  'end',
#  'year',
#  'doe',
#  'instead',
#  'offer',
#  '  ',
#  'billion',
#  'multiyear',
#  'fund',
#  'project',
#  'uamp',
#  'subscrib',
#  'drop',
#  'project',
#  'offtak',
#  'substanti',
#  'reduc',
#  'commit',
#  ' ',
#  'ocean',
#  'nuscal',
#  'launch',
#  'play',
#  'uk',
#  'market',
#  'memorandum',
#  'understand',
#  'startup',
#  'clean',
#  'energi',
#  'firm',
#  'shearwat',
#  'energi',
#  'explor',
#  'deploy',
#  'hybrid',
#  'smr',
#  'wind',
#  'energi',
#  'project',
#  'countri',
#  'compani',
#  'hope',
#  'score',
#  'flagship',
#  'site',
#  'near',
#  'wylfa',
#  'plant',
#  'north',
#  'wale',
#  'year',
#  'hitachi',
#  'decid',
#  'wind',
#  'advanc',
#  'boil',
#  'water',
#  'reactor',
#  ' ',
#  'abwr',
#  'project',
#  'develop',
#  'compani',
#  ' ',
#  'niw',
#  'sep',
#  'wylfa',
#  'smrwind',
#  'plant',
#  ' ',
#  'provid',
#  ' ',
#  'gw',
#  'reliabl',
#  'zerocarbon',
#  'electr',
#  'fraction',
#  'cost',
#  'convent',
#  'nuclear',
#  'power',
#  'station',
#  'surplus',
#  'energi',
#  'generat',
#  'focus',
#  'product',
#  'hydrogen',
#  'support',
#  'transport',
#  'sector',
#  's',
#  'transit',
#  'lowcarbon',
#  'fuel',
#  ' ',
#  'shearwat',
#  'ceo',
#  'simon',
#  'forster',
#  'said',
#  'jan',
#  ' ',
#  'statement',
#  'shearwat',
#  'incorpor',
#  ' ',
#  'way',
#  'forward',
#  'project',
#  'like',
#  'depend',
#  'suitabl',
#  'attract',
#  'econom',
#  'uk',
#  'govern',
#  'nuclear',
#  'subsidi',
#  'regim',
#  'plus',
#  'lock',
#  'site',
#  'grab',
#  'interest',
#  'consortium',
#  ' ',
#  'relat']

# %%
df.head()
# Out:
#                                                title  \
# 0  qatar to slash emissions as lng expansion adva...
# 1                  india launches its first  mw phwr
# 2               new chapter for uschina energy trade
# 3     japan slow restarts cast doubt on  energy plan
# 4     nyc pension funds to divest fossil fuel shares
#
#                                              content       domain  \
# 0  qatar petroleum  qp is targeting aggressive cu...  energyintel
# 1  nuclear power corp of india ltd  npcil synchro...  energyintel
# 2  new us president joe biden took office this we...  energyintel
# 3  the slow pace of japanese reactor restarts con...  energyintel
# 4  two of new york citys largest pension funds sa...  energyintel
#
#                                          token_title  \
# 0  [qatar, slash, emissions, lng, expansion, adva...
# 1                     [india, launches,  , mw, phwr]
# 2             [new, chapter, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt,  , energy...
# 4  [nyc, pension, funds, divest, fossil, fuel, sh...
#
#                                  token_words_content   token_domain  \
# 0  [qatar, petroleum,  , qp, targeting, aggressiv...  [energyintel]
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...  [energyintel]
# 2  [new, president, joe, biden, took, office, wee...  [energyintel]
# 3  [slow, pace, japanese, reactor, restarts, cont...  [energyintel]
# 4  [new, york, citys, largest, pension, funds, di...  [energyintel]
#
#                                  token_sents_content  \
# 0  [qatar petroleum  qp is targeting aggressive c...
# 1  [nuclear power corp of india ltd  npcil synchr...
# 2  [new us president joe biden took office this w...
# 3  [the slow pace of japanese reactor restarts co...
# 4  [two of new york citys largest pension funds s...
#
#                  token_sents_content_without_process  \
# 0  [["Qatar Petroleum ( QP) is targeting aggressi...
# 1  [[" Nuclear Power Corp. of India Ltd. ( NPCIL)...
# 2  [["New US President Joe Biden took office this...
# 3  [["The slow pace of Japanese reactor restarts ...
# 4  [["Two of New York City's largest pension fund...
#
#                                          lemma_title  \
# 0  [qatar, slash, emission, lng, expansion, advance]
# 1                       [india, launch,  , mw, phwr]
# 2             [new, chapter, uschina, energy, trade]
# 3  [japan, slow, restarts, cast, doubt,  , energy...
# 4  [nyc, pension, fund, divest, fossil, fuel, share]
#
#                                        lemma_content  \
# 0  [qatar, petroleum,  , qp, targeting, aggressiv...
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...
# 2  [new, president, joe, biden, took, office, wee...
# 3  [slow, pace, japanese, reactor, restarts, cont...
# 4  [new, york, city, largest, pension, fund, dive...
#
#                                  lemma_spacy_content  \
# 0  [qatar, petroleum,   , qp, target, aggressive,...
# 1  [nuclear, power, corp, india, ltd,   , npcil, ...
# 2  [new, president, joe, biden, take, office, wee...
# 3  [slow, pace, japanese, reactor, restart, conti...
# 4  [new, york, city, large, pension, fund, divest...
#
#                                        stemm_content
# 0  [qatar, petroleum,  , qp, target, aggress, cut...
# 1  [nuclear, power, corp, india, ltd,  , npcil, s...
# 2  [new, presid, joe, biden, took, offic, week, u...
# 3  [slow, pace, japanes, reactor, restart, contin...
# 4  [new, york, citi, largest, pension, fund, dive...
